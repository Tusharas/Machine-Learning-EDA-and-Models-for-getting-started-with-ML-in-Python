# %% [raw]
# author:Tushara S
#
# Created on 15 September 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
    
#1.Read the dataset and do all the for  given dataset. (head, tail, describe, info,Columns, values )
data3 = pd.read_csv('data.csv')
data3.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data3.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
data3.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
list(data3.columns.values)
# Out:
# ['id',
#  'diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst',
#  'Unnamed: 32']

# %%
#2.Summary Statistics for only for radius_mean column. 

data3[["radius_mean"]].describe()
# Out:
#        radius_mean
# count   569.000000
# mean     14.127292
# std       3.524049
# min       6.981000
# 25%      11.700000
# 50%      13.370000
# 75%      15.780000
# max      28.110000

# %%
#3.Check if null values are present in the dataset.
data3.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
#4.Draw a Histogram of Radius Mean for Bening and Malignant Tumors.
ax = data3.hist(column='radius_mean', by=data3['diagnosis'] ,bins=25, grid=False, figsize=(12,8), zorder=2, rwidth=0.9)

# %%
#5.For data_bening.radius_mean column find the outliers and print the range of outliers and outliers values.
#The interquartile range (IQR), also called the midspread or middle 50%, or technically H-spread, is a measure of statistical dispersion, being equal to the difference between 75th and 25th percentiles, or between upper and lower quartiles, IQR = Q3 − Q1.
data_bening_radius_mean=  data3.loc[data3['diagnosis'] == 'B', 'radius_mean']

Q1 = np.percentile(data_bening_radius_mean, 25, interpolation = 'midpoint')  
Q2 = np.percentile(data_bening_radius_mean, 50, interpolation = 'midpoint')  
Q3 = np.percentile(data_bening_radius_mean, 75, interpolation = 'midpoint')  
  
print('Q1 25 percentile of the given data is, ', Q1) 
print('Q1 50 percentile of the given data is, ', Q2) 
print('Q1 75 percentile of the given data is, ', Q3) 
  
IQR = Q3 - Q1  
print('Range is', IQR) 
print(data3['radius_mean'] < (Q1 - 1.5 * IQR)) , (data3['radius_mean'] > (Q3 + 1.5 * IQR))
# Out:
# Q1 25 percentile of the given data is,  11.08
# Q1 50 percentile of the given data is,  12.2
# Q1 75 percentile of the given data is,  13.37
# Range is 2.289999999999999
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 564    False
# 565    False
# 566    False
# 567    False
# 568    False
# Name: radius_mean, Length: 569, dtype: bool
# (None, 0       True
#  1       True
#  2       True
#  3      False
#  4       True
#         ...
#  564     True
#  565     True
#  566    False
#  567     True
#  568    False
#  Name: radius_mean, Length: 569, dtype: bool)

# %%
#6.Draw a Box plot for 'radius_mean', 'texture_mean’
boxplot = data3.boxplot(column=['radius_mean', 'texture_mean'])

# %%
#7.Find the correlation between all features using Correlation Map.
corrMatrix = data3.corr()
plt.figure(figsize=(10,15))
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
#In the covariance matrix in the output, the off-diagonal elements contain the covariances of each pair of variables. 
#The diagonal elements of the covariance matrix contain the variances of each variable.
#The variance measures how much the data are scattered about the mean.
data3.cov()
# Out:
#                                    id   radius_mean  texture_mean  \
# id                       1.563015e+16  3.287883e+07  5.364807e+07
# radius_mean              3.287883e+07  1.241892e+01  4.907582e+00
# texture_mean             5.364807e+07  4.907582e+00  1.849891e+01
# perimeter_mean           2.222490e+08  8.544714e+01  3.443976e+01
# area_mean                4.262946e+09  1.224483e+03  4.859938e+02
# smoothness_mean         -2.280205e+04  8.454460e-03 -1.414779e-03
# compactness_mean         6.318839e+02  9.419706e-02  5.376681e-02
# concavity_mean           4.991277e+05  1.901276e-01  1.036923e-01
# concave points_mean      2.142177e+05  1.124751e-01  4.897693e-02
# symmetry_mean           -7.579262e+04  1.427317e-02  8.418876e-03
# fractal_dimension_mean  -4.635137e+04 -7.753706e-03 -2.321158e-03
# radius_se                4.959431e+06  6.636503e-01  3.290374e-01
# texture_se              -5.190618e+05 -1.891886e-01  9.166951e-01
# ...

# %%
#8.Calculate Covariance between radius mean and area mean
data3.radius_mean.cov(data3.area_mean)
# Out:
# 1224.4834093464565

# %%
#9.Calculate Covariance between radius mean and fractal dimension se 
data3.radius_mean.cov(data3.fractal_dimension_se)
# Out:
# -0.0003976248576440626
